# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
import seaborn as sns

# %% [markdown]
# # LOADING THE DATA-SETS

# %%
new = pd.read_csv('typhoon_data.csv', parse_dates={'Date': ['day', 'month', 'year']}, index_col=[0,2])
new
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_11628\1798202717.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   new = pd.read_csv('typhoon_data.csv', parse_dates={'Date': ['day', 'month', 'year']}, index_col=[0,2])
#                                     Unnamed: 0  hour  \
# Date       International number ID
# 1951-02-19 5101                              0     6
#            5101                              1    12
#            5101                              2    18
# 1951-02-20 5101                              3     0
#            5101                              4     6
# ...                                        ...   ...
# 2022-11-12 2225                          68619    12
#            2225                          68620    18
# 2022-12-12 2225                          68621     0
# ...

# %%
#lets make the dupicate of it
data = new.copy()

# %%
data
# Out:
#                                     Unnamed: 0  hour  \
# Date       International number ID
# 1951-02-19 5101                              0     6
#            5101                              1    12
#            5101                              2    18
# 1951-02-20 5101                              3     0
#            5101                              4     6
# ...                                        ...   ...
# 2022-11-12 2225                          68619    12
#            2225                          68620    18
# 2022-12-12 2225                          68621     0
#            2225                          68622     6
#            2225                          68623    12
#
#                                                                          grade  \
# Date       International number ID
# 1951-02-19 5101                                            Tropical Depression
#            5101                                            Tropical Depression
# ...

# %% [markdown]
# # DATA PRE-PROCESSING

# %%
data
# Out:
#                                     Unnamed: 0  hour  \
# Date       International number ID
# 1951-02-19 5101                              0     6
#            5101                              1    12
#            5101                              2    18
# 1951-02-20 5101                              3     0
#            5101                              4     6
# ...                                        ...   ...
# 2022-11-12 2225                          68619    12
#            2225                          68620    18
# 2022-12-12 2225                          68621     0
#            2225                          68622     6
#            2225                          68623    12
#
#                                                                          grade  \
# Date       International number ID
# 1951-02-19 5101                                            Tropical Depression
#            5101                                            Tropical Depression
# ...

# %%
data = data.drop(columns = 'Unnamed: 0')

# %%
data.describe()
# Out:
#                hour  Latitude of the center  Longitude of the center  \
# count  68624.000000            68624.000000             68624.000000
# mean       9.065691              225.740616              1361.872421
# std        6.733798              106.723343               170.226026
# min        0.000000               14.000000               950.000000
# 25%        3.000000              148.000000              1241.000000
# 50%        9.000000              204.000000              1343.000000
# 75%       15.000000              282.000000              1470.000000
# max       23.000000              690.000000              1880.000000
#
#        Central pressure  Maximum sustained wind speed  \
# count      68624.000000                  43356.000000
# mean         984.356333                     37.593413
# std           22.379916                     32.863317
# min          870.000000                      0.000000
# 25%          975.000000                      0.000000
# ...

# %%
data.isna()
# Out:
#                                      hour  grade  Latitude of the center  \
# Date       International number ID
# 1951-02-19 5101                     False  False                   False
#            5101                     False  False                   False
#            5101                     False  False                   False
# 1951-02-20 5101                     False  False                   False
#            5101                     False  False                   False
# ...                                   ...    ...                     ...
# 2022-11-12 2225                     False  False                   False
#            2225                     False  False                   False
# 2022-12-12 2225                     False  False                   False
#            2225                     False  False                   False
#            2225                     False  False                   False
#
# ...

# %%
data.isnull().sum()
# Out:
# hour                                                            0
# grade                                                           0
# Latitude of the center                                          0
# Longitude of the center                                         0
# Central pressure                                                0
# Maximum sustained wind speed                                25268
# Direction of the longest radius of 50kt winds or greater    41416
# The longeast radius of 50kt winds or greater                41416
# The shortest radius of 50kt winds or greater                41416
# Direction of the longest radius of 30kt winds or greater    41416
# The longeast radius of 30kt winds or greater                41416
# The shortest radius of 30kt winds or greater                41416
# Indicator of landfall or passage                                0
# dtype: int64

# %%
#removing the Null Values
#copying into the new file

df = data.copy()

# %%
df
# Out:
#                                     hour  \
# Date       International number ID
# 1951-02-19 5101                        6
#            5101                       12
#            5101                       18
# 1951-02-20 5101                        0
#            5101                        6
# ...                                  ...
# 2022-11-12 2225                       12
#            2225                       18
# 2022-12-12 2225                        0
#            2225                        6
#            2225                       12
#
#                                                                          grade  \
# Date       International number ID
# 1951-02-19 5101                                            Tropical Depression
#            5101                                            Tropical Depression
#            5101                                            Tropical Depression
# ...

# %%
df.columns
# Out:
# Index(['hour', 'grade', 'Latitude of the center', 'Longitude of the center',
#        'Central pressure', 'Maximum sustained wind speed',
#        'Direction of the longest radius of 50kt winds or greater',
#        'The longeast radius of 50kt winds or greater',
#        'The shortest radius of 50kt winds or greater',
#        'Direction of the longest radius of 30kt winds or greater',
#        'The longeast radius of 30kt winds or greater',
#        'The shortest radius of 30kt winds or greater',
#        'Indicator of landfall or passage'],
#       dtype='object')

# %%
df = df.dropna(how = 'any')

# %%
df
# Out:
#                                     hour                  grade  \
# Date       International number ID
# 1977-03-28 7701                        0  Severe Tropical Storm
#            7701                        6  Severe Tropical Storm
#            7701                       12  Severe Tropical Storm
#            7701                       18         Tropical Storm
# 1977-03-29 7701                        0         Tropical Storm
# ...                                  ...                    ...
# 2022-11-14 2224                        0         Tropical Storm
# 2022-11-12 2225                       12         Tropical Storm
#            2225                       18         Tropical Storm
# 2022-12-12 2225                        0         Tropical Storm
#            2225                        6         Tropical Storm
#
#                                     Latitude of the center  \
# Date       International number ID
# 1977-03-28 7701                                         56
# ...

# %%
# storing the data in the final result
data_new = df.copy()

# %%
#let's verify 
data_new
# Out:
#                                     hour                  grade  \
# Date       International number ID
# 1977-03-28 7701                        0  Severe Tropical Storm
#            7701                        6  Severe Tropical Storm
#            7701                       12  Severe Tropical Storm
#            7701                       18         Tropical Storm
# 1977-03-29 7701                        0         Tropical Storm
# ...                                  ...                    ...
# 2022-11-14 2224                        0         Tropical Storm
# 2022-11-12 2225                       12         Tropical Storm
#            2225                       18         Tropical Storm
# 2022-12-12 2225                        0         Tropical Storm
#            2225                        6         Tropical Storm
#
#                                     Latitude of the center  \
# Date       International number ID
# 1977-03-28 7701                                         56
# ...

# %% [markdown]
# Differnce of before and after Preprocessing of the data

# %%
data.isna().sum()
# Out:
# hour                                                            0
# grade                                                           0
# Latitude of the center                                          0
# Longitude of the center                                         0
# Central pressure                                                0
# Maximum sustained wind speed                                25268
# Direction of the longest radius of 50kt winds or greater    41416
# The longeast radius of 50kt winds or greater                41416
# The shortest radius of 50kt winds or greater                41416
# Direction of the longest radius of 30kt winds or greater    41416
# The longeast radius of 30kt winds or greater                41416
# The shortest radius of 30kt winds or greater                41416
# Indicator of landfall or passage                                0
# dtype: int64

# %%
data_new.isna().sum()
# Out:
# hour                                                        0
# grade                                                       0
# Latitude of the center                                      0
# Longitude of the center                                     0
# Central pressure                                            0
# Maximum sustained wind speed                                0
# Direction of the longest radius of 50kt winds or greater    0
# The longeast radius of 50kt winds or greater                0
# The shortest radius of 50kt winds or greater                0
# Direction of the longest radius of 30kt winds or greater    0
# The longeast radius of 30kt winds or greater                0
# The shortest radius of 30kt winds or greater                0
# Indicator of landfall or passage                            0
# dtype: int64

# %%
sample = data_new[:1000]

# %%
sample.columns = ['hour', 'grade', 'LaC', 'Loc', 'cp', 'MSWS', 'dlr', 'tlr', 'tsr', 'dlr30', 'tlr30', 'tsr30', 'droper']

# %%
sample.drop(columns='droper')
# Out:
#                                     hour                  grade  LaC   Loc  \
# Date       International number ID
# 1977-03-28 7701                        0  Severe Tropical Storm   56  1588
#            7701                        6  Severe Tropical Storm   61  1582
#            7701                       12  Severe Tropical Storm   66  1575
#            7701                       18         Tropical Storm   70  1568
# 1977-03-29 7701                        0         Tropical Storm   73  1560
# ...                                  ...                    ...  ...   ...
# 1978-10-22 7826                       18                Typhoon  117  1499
# 1978-10-23 7826                        0                Typhoon  117  1485
#            7826                        6                Typhoon  118  1471
#            7826                       12                Typhoon  120  1456
#            7826                       18                Typhoon  120  1436
#
# ...

# %%
sample['MSWS'].dtypes
# Out:
# dtype('float64')

# %%
sample['MSWS'] = sample['MSWS'].astype(int)
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_11628\2223867584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['MSWS'] = sample['MSWS'].astype(int)

# %%
sample['tlr'] = sample['tlr'].astype(int)
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_11628\4038283094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['tlr'] = sample['tlr'].astype(int)

# %%
sample['tsr'] = sample['tsr'].astype(int)
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_11628\228204704.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['tsr'] = sample['tsr'].astype(int)

# %%
sample['tlr30'] = sample['tlr30'].astype(int)
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_11628\4279456285.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['tlr30'] = sample['tlr30'].astype(int)

# %%
sample['tsr30'] = sample['tsr30'].astype(int)
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_11628\2596587882.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample['tsr30'] = sample['tsr30'].astype(int)

# %%
sample
# Out:
#                                     hour                  grade  LaC   Loc  \
# Date       International number ID
# 1977-03-28 7701                        0  Severe Tropical Storm   56  1588
#            7701                        6  Severe Tropical Storm   61  1582
#            7701                       12  Severe Tropical Storm   66  1575
#            7701                       18         Tropical Storm   70  1568
# 1977-03-29 7701                        0         Tropical Storm   73  1560
# ...                                  ...                    ...  ...   ...
# 1978-10-22 7826                       18                Typhoon  117  1499
# 1978-10-23 7826                        0                Typhoon  117  1485
#            7826                        6                Typhoon  118  1471
#            7826                       12                Typhoon  120  1456
#            7826                       18                Typhoon  120  1436
#
# ...

# %%
sample
# Out:
#                                     hour                  grade  LaC   Loc  \
# Date       International number ID
# 1977-03-28 7701                        0  Severe Tropical Storm   56  1588
#            7701                        6  Severe Tropical Storm   61  1582
#            7701                       12  Severe Tropical Storm   66  1575
#            7701                       18         Tropical Storm   70  1568
# 1977-03-29 7701                        0         Tropical Storm   73  1560
# ...                                  ...                    ...  ...   ...
# 1978-10-22 7826                       18                Typhoon  117  1499
# 1978-10-23 7826                        0                Typhoon  117  1485
#            7826                        6                Typhoon  118  1471
#            7826                       12                Typhoon  120  1456
#            7826                       18                Typhoon  120  1436
#
# ...

# %%
sample.corr()
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_11628\3551824402.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sample.corr()
#            hour       LaC       Loc        cp      MSWS       tlr       tsr  \
# hour   1.000000  0.003761 -0.007460 -0.005917  0.005709  0.005660  0.008553
# LaC    0.003761  1.000000  0.126281  0.050409 -0.083734 -0.001181 -0.014179
# Loc   -0.007460  0.126281  1.000000 -0.029755  0.019816 -0.005119 -0.009625
# cp    -0.005917  0.050409 -0.029755  1.000000 -0.906485 -0.707848 -0.677738
# MSWS   0.005709 -0.083734  0.019816 -0.906485  1.000000  0.832877  0.807922
# tlr    0.005660 -0.001181 -0.005119 -0.707848  0.832877  1.000000  0.982891
# tsr    0.008553 -0.014179 -0.009625 -0.677738  0.807922  0.982891  1.000000
# ...

# %%
sns.heatmap(sample.corr())
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_11628\442824108.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(sample.corr())
# <AxesSubplot: >

# %%
x = sample['MSWS']
y = sample['tlr']

# %%
plt.subplot(3,2,1)
sns.barplot(x = x, y = y, data = data_new)
plt.xticks(rotation = 90)
plt.subplot(3,2,2)
sns.lineplot(x = x, y= y, data =data_new)
# Out:
# <AxesSubplot: xlabel='MSWS', ylabel='tlr'>

# %%
sns.lineplot(x = x, y= y, data =data_new)
# Out:
# <AxesSubplot: xlabel='MSWS', ylabel='tlr'>

# %%
x = sample['MSWS']
y = sample['tsr']

# %%
sns.barplot(x = x, y = y, data = data_new)
# Out:
# <AxesSubplot: xlabel='MSWS', ylabel='tsr'>

# %%
x = sample['MSWS']
y = sample['tlr30']

# %%
sns.barplot(x = x, y = y, data = sample)
# Out:
# <AxesSubplot: xlabel='MSWS', ylabel='tlr30'>

# %%
sns.lineplot(x = x, y = y, data = sample)
# Out:
# <AxesSubplot: xlabel='MSWS', ylabel='tlr30'>

# %%
a = sample['MSWS']
b = sample['tlr']
c = sample['MSWS']
d = sample['tsr']
e = sample['MSWS']
f = sample['tlr30']
g = sample['MSWS']
h = sample['tsr30']

# %%
sns.lineplot(x = a, y = b, data = sample, color ='r')
sns.lineplot(x = e, y = f, data = sample, color = 'g')
plt.legend()
plt.show()
sns.lineplot(x = c, y = d, data = sample, color = 'b')
sns.lineplot(x = g, y = h, data = sample, color = 'purple')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sample.columns
# Out:
# Index(['hour', 'grade', 'LaC', 'Loc', 'cp', 'MSWS', 'dlr', 'tlr', 'tsr',
#        'dlr30', 'tlr30', 'tsr30', 'droper'],
#       dtype='object')

# %%
a = sample['cp']
b = sample['tlr']
c = sample['cp']
d = sample['MSWS']
e = sample['cp']
f = sample['tlr30']
g = sample['cp']
h = sample['tsr30']
i = sample['cp']
j = sample['tsr']

# %%
sns.lineplot(x = a, y = b, data = sample)
# Out:
# <AxesSubplot: xlabel='cp', ylabel='tlr'>

# %%
sns.lineplot(x = i, y = j,data = sample)
# Out:
# <AxesSubplot: xlabel='cp', ylabel='tsr'>

# %%
sns.lineplot(x = c, y = d, data = sample)
# Out:
# <AxesSubplot: xlabel='cp', ylabel='MSWS'>

# %%
sns.lineplot(x = e, y = f, data = sample)
# Out:
# <AxesSubplot: xlabel='cp', ylabel='tlr30'>

# %%
sns.lineplot(x = g, y = h, data = sample)
# Out:
# <AxesSubplot: xlabel='cp', ylabel='tsr30'>

# %%
#to more clear or for good mutual understanding
sns.lineplot(x = a, y = b, data = sample, color = 'purple', ci = None)
sns.lineplot(x = c, y = d, data = sample,color = 'b', ci = None)
sns.lineplot(x = e, y = f, data = sample, color = 'y', ci = None)
sns.lineplot(x = g, y = h, data = sample, color = 'r', linestyle = 'dashed', alpha = 0.4, ci = None)
sns.lineplot(x = i, y = j, data = sample, color = 'green', ci = None)
plt.legend()
plt.title('MIXED OF ALL WITH CENTRAL PRESSURE')
plt.show()
# Out:
# C:\Users\bhara\AppData\Local\Temp\ipykernel_11628\680919439.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x = a, y = b, data = sample, color = 'purple', ci = None)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_11628\680919439.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x = c, y = d, data = sample,color = 'b', ci = None)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_11628\680919439.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x = e, y = f, data = sample, color = 'y', ci = None)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_11628\680919439.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x = g, y = h, data = sample, color = 'r', linestyle = 'dashed', alpha = 0.4, ci = None)
# ...

# %%
sns.violinplot(x = x, y = y, data= sample)
# Out:
# <AxesSubplot: xlabel='MSWS', ylabel='tlr30'>

# %% [markdown]
# # MODEL BUILDING AND DEPLOYMENT UNIT

# %%
sample
# Out:
#                                     hour                  grade  LaC   Loc  \
# Date       International number ID
# 1977-03-28 7701                        0  Severe Tropical Storm   56  1588
#            7701                        6  Severe Tropical Storm   61  1582
#            7701                       12  Severe Tropical Storm   66  1575
#            7701                       18         Tropical Storm   70  1568
# 1977-03-29 7701                        0         Tropical Storm   73  1560
# ...                                  ...                    ...  ...   ...
# 1978-10-22 7826                       18                Typhoon  117  1499
# 1978-10-23 7826                        0                Typhoon  117  1485
#            7826                        6                Typhoon  118  1471
#            7826                       12                Typhoon  120  1456
#            7826                       18                Typhoon  120  1436
#
# ...

# %%
#lets predict the central pressure('CP') with the help of the MSWS, tlr30, tsr30, Loc and Lac
#loading the model while we are using the Decision tree classifier 
#we are alos load and do feature selction for the model fitting
#X_t = ['Lac', 'Loc', 'MSWS', 'tlr', 'tsr', 'tlr30', 'tsr30']
#X = sample[['Lac', 'Loc', 'MSWS', 'tlr', 'tsr', 'tlr30', 'tsr30']]
X = sample.iloc[:, [2, 3, 5]]
Y = sample['cp']
X
# Out:
#                                     LaC   Loc  MSWS
# Date       International number ID
# 1977-03-28 7701                      56  1588    50
#            7701                      61  1582    50
#            7701                      66  1575    50
#            7701                      70  1568    45
# 1977-03-29 7701                      73  1560    45
# ...                                 ...   ...   ...
# 1978-10-22 7826                     117  1499   110
# 1978-10-23 7826                     117  1485   110
#            7826                     118  1471   110
#            7826                     120  1456   120
#            7826                     120  1436   110
#
# [1000 rows x 3 columns]

# %%
#model loading and deployment
tree = DecisionTreeClassifier()
tree.fit(X, Y)
# Out:
# DecisionTreeClassifier()

# %%
prediction = tree.predict([[73, 1560, 45]])
print("The Central Pressure is : ", prediction)
# Out:
# The Central Pressure is :  [1002]
# C:\Users\bhara\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
tree.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
PcPrediction = tree.predict(X_test)

# %%
score = accuracy_score(Y_test, PcPrediction)
score
# Out:
# 0.35

# %%
#Let's predict the grade with help of wind speed Lac, Loc, MSWS, tlr30, tsr30
X = sample.iloc[:, [2, 3, 5, 10, 11]]
Y = sample['grade']
Y
# Out:
# Date        International number ID
# 1977-03-28  7701                       Severe Tropical Storm
#             7701                       Severe Tropical Storm
#             7701                       Severe Tropical Storm
#             7701                              Tropical Storm
# 1977-03-29  7701                              Tropical Storm
#                                                ...
# 1978-10-22  7826                                     Typhoon
# 1978-10-23  7826                                     Typhoon
#             7826                                     Typhoon
#             7826                                     Typhoon
#             7826                                     Typhoon
# Name: grade, Length: 1000, dtype: object

# %%
tree.fit(X, Y)
# Out:
# DecisionTreeClassifier()

# %%
X
# Out:
#                                     LaC   Loc  MSWS  tlr30  tsr30
# Date       International number ID
# 1977-03-28 7701                      56  1588    50    125    125
#            7701                      61  1582    50    125    125
#            7701                      66  1575    50    125    125
#            7701                      70  1568    45    100    100
# 1977-03-29 7701                      73  1560    45    100    100
# ...                                 ...   ...   ...    ...    ...
# 1978-10-22 7826                     117  1499   110    150    100
# 1978-10-23 7826                     117  1485   110    175    175
#            7826                     118  1471   110    175    175
#            7826                     120  1456   120    175    175
#            7826                     120  1436   110    175    175
#
# [1000 rows x 5 columns]

# %%
prediction2 = tree.predict([[117, 1499, 110, 150, 100]])
print("The predicted Grade is all about the required data which is denoted to X is : ", prediction2)
# Out:
# The predicted Grade is all about the required data which is denoted to X is :  ['Typhoon']
# C:\Users\bhara\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
X_ntrain, X_ntest, Y_ntrain, Y_ntest = train_test_split(X,Y, test_size=0.3)

# %%
tree.fit(X_ntrain, Y_ntrain)
# Out:
# DecisionTreeClassifier()

# %%
predictionN = tree.predict(X_ntest)

# %%
scoreN = accuracy_score(Y_ntest, predictionN)
scoreN
# Out:
# 1.0

# %% [markdown]
# # COMPLETED              --------------END--------------
